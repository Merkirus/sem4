# %%
import pandas as pd

# %%
data = pd.read_csv('Milan.csv')

# %%
data
# Out:
#                   player  shirtnumber nationality position  age  minutes  \
# 0             Ante Rebić           12         CRO       FW   28       57
# 1         Olivier Giroud            9         FRA       FW   35       33
# 2            Rafael Leão           17         POR       LW   23       65
# 3           Divock Origi           27         BEL       LW   27       25
# 4         Junior Messias           30         BRA       RW   31       65
# 5    Alexis Saelemaekers           56         BEL       RW   23       25
# 6            Brahim Díaz           10         ESP       AM   23       57
# 7   Charles De Ketelaere           90         BEL       AM   21       33
# 8          Sandro Tonali            8         ITA       DM   22       90
# 9        Ismaël Bennacer            4         ALG       DM   24       90
# 10        Theo Hernández           19         FRA       LB   24       90
# 11         Fikayo Tomori           23         ENG       CB   24       90
# ...

# %%
data = pd.read_csv('Milan_shots.csv')

# %%
data
# Out:
#     minute           player   team  xg_shot  psxg_shot     outcome  distance  \
# 0        1      Rafael Leão  Milan     0.09        NaN  Off Target        14
# 1        3      Rafael Leão  Milan     0.05       0.12       Saved        16
# 2       19    Sandro Tonali  Milan     0.05        NaN  Off Target        26
# 3       22   Theo Hernández  Milan     0.02        NaN     Blocked        31
# 4       23   Junior Messias  Milan     0.12        NaN  Off Target        10
# 5       30   Theo Hernández  Milan     0.03        NaN  Off Target        29
# 6       32    Pierre Kalulu  Milan     0.12        NaN  Off Target         9
# 7       34      Rafael Leão  Milan     0.02       0.21       Saved        32
# 8       43   Theo Hernández  Milan     0.04        NaN     Blocked        27
# 9       45  Davide Calabria  Milan     0.02        NaN  Off Target        30
# 10      50    Pierre Kalulu  Milan     0.36        NaN  Off Target         7
# ...
